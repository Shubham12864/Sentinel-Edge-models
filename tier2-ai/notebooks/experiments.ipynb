# %% [markdown]
# # YOLO26n people detection experiments
# This notebook is for quick model testing and not production deployment.

# %%
from pathlib import Path
print('Project root:', Path.cwd())
print('YOLO26n model directory exists:', (Path.cwd() / 'models' / 'yolo26n').exists())
